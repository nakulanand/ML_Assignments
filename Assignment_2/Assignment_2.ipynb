# %%
import numpy as np

# %%
# Question 1
ar1 = np.random.rand(10,1)
print(ar1)
print(np.mean(ar1))
# Out:
# [[0.22182534]
#  [0.7804229 ]
#  [0.83531986]
#  [0.50026597]
#  [0.29002683]
#  [0.98995659]
#  [0.41776228]
#  [0.78106512]
#  [0.05800347]
#  [0.77703596]]
# 0.5651684320861186

# %%
# Question - 2

ar1 = np.random.rand(20,1)
print(np.var(ar1))
print(np.std(ar1))
# Out:
# 0.08705950274012887
# 0.29505847342540237

# %%
# Question 3

a1 = np.random.rand(10,20)
a2 = np.random.rand(20,25)
c = np.matmul(a1, a2)
print(c)
print(c.sum())
# Out:
# [[6.29108635 5.78291896 5.82952713 6.42139302 5.68146878 5.31484931
#   6.75111664 5.46452266 6.03500225 8.11947012 5.34038652 5.54019466
#   6.10808253 6.65775501 6.78019026 5.32228855 6.31182578 5.67971964
#   5.28944198 5.76293659 5.91391252 5.39308281 4.46559553 5.4577675
#   4.97766257]
#  [5.97442451 5.25045764 5.76165241 5.50598696 5.95506035 5.59855661
#   6.33571606 5.19175298 5.78063257 7.7189223  5.20414224 6.12811306
#   5.71874863 6.76941577 6.44985721 5.05903497 6.07932299 5.1056069
#   5.20189458 5.62509885 5.66880264 5.2295858  4.67583023 5.55608634
#   5.02784906]
#  [6.55441739 5.44158518 6.1264201  6.67874838 6.53278249 5.62249034
#   7.07194795 5.07806136 6.94824408 7.88895276 5.83631363 6.90697714
#   7.33992014 7.83442901 7.29782646 5.39265263 6.53532656 6.02623654
#   5.64018747 6.50332493 6.00068966 5.58507099 5.42867345 5.94796672
#   5.21358275]
#  [6.93244291 5.87864083 5.78832822 6.12158175 5.90302811 6.40345007
# ...

# %%
# Question 4

def f(x):
    return 1 / (1 + np.exp(-x))

d = np.random.rand(10,1)
print(f(d))
# Out:
# [[0.65528047]
#  [0.58387029]
#  [0.67981556]
#  [0.67433713]
#  [0.61554117]
#  [0.57417294]
#  [0.69985134]
#  [0.72432405]
#  [0.56799537]
#  [0.5985736 ]]
